# %%
# Research question
## The relationships of people's willingness to rent bike on different kind of day. Such as, holiday and working day, but especially looking at the 
## temperature, humidity and windspeed of the day.
# Additional research
## Difference between registered user and unregistered user

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append('../../data/raw')

# %%
df = pd.read_csv('../../data/raw/day_processed.csv')
df
# Out:
#      Unnamed: 0  instant      dteday  holiday  workingday      temp       hum  \
# 0             0        1  2011-01-01        0           0  0.344167  0.805833
# 1             1        2  2011-01-02        0           0  0.363478  0.696087
# 2             2        3  2011-01-03        0           1  0.196364  0.437273
# 3             3        4  2011-01-04        0           1  0.200000  0.590435
# 4             4        5  2011-01-05        0           1  0.226957  0.436957
# ..          ...      ...         ...      ...         ...       ...       ...
# 726         726      727  2012-12-27        0           1  0.254167  0.652917
# 727         727      728  2012-12-28        0           1  0.253333  0.590000
# 728         728      729  2012-12-29        0           0  0.253333  0.752917
# 729         729      730  2012-12-30        0           0  0.255833  0.483333
# 730         730      731  2012-12-31        0           1  0.215833  0.577500
#
# ...

# %%
df.shape
# Out:
# (731, 11)

# %%
df = df[df['holiday']==1]
df
# Out:
#      Unnamed: 0  instant      dteday  holiday  workingday      temp       hum  \
# 16           16       17  2011-01-17        1           0  0.175833  0.537500
# 51           51       52  2011-02-21        1           0  0.303333  0.605000
# 104         104      105  2011-04-15        1           0  0.446667  0.671250
# 149         149      150  2011-05-30        1           0  0.733333  0.685000
# 184         184      185  2011-07-04        1           0  0.726667  0.637917
# 247         247      248  2011-09-05        1           0  0.673333  0.790417
# 282         282      283  2011-10-10        1           0  0.570833  0.733750
# 314         314      315  2011-11-11        1           0  0.324167  0.446250
# 327         327      328  2011-11-24        1           0  0.373333  0.549167
# 359         359      360  2011-12-26        1           0  0.321739  0.506957
# 366         366      367  2012-01-02        1           0  0.273043  0.381304
# ...

# %%
df.describe().T
# Out:
#             count         mean          std          min          25%  \
# Unnamed: 0   21.0   384.809524   215.542251    16.000000   247.000000
# instant      21.0   385.809524   215.542251    17.000000   248.000000
# holiday      21.0     1.000000     0.000000     1.000000     1.000000
# workingday   21.0     0.000000     0.000000     0.000000     0.000000
# temp         21.0     0.465012     0.202275     0.175833     0.303333
# hum          21.0     0.614704     0.114579     0.381304     0.537500
# windspeed    21.0     0.193319     0.079659     0.042304     0.151121
# casual       21.0  1064.714286   860.046809   117.000000   440.000000
# registered   21.0  2670.285714  1492.860246   573.000000  1470.000000
# cnt          21.0  3735.000000  2103.350660  1000.000000  1951.000000
#
#                     50%          75%          max
# Unnamed: 0   366.000000   550.000000   724.000000
# instant      367.000000   551.000000   725.000000
# ...

# %%
sns.pairplot(df)

# %%
df.boxplot('temp')
# Out:
# <AxesSubplot:>

# %%
df.boxplot('hum')
# Out:
# <AxesSubplot:>

# %%
df.boxplot('windspeed')
# Out:
# <AxesSubplot:>

# %%
hist = df.hist(bins=10, figsize = (10, 10))
